# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
np.random.seed(240)
img = plt.imread("to the moon.jpg")
offsetArr1 = np.random.randint(low=0, high=255, size=img.shape[1])
offsetMtx1 = np.tile(offsetArr1, (img.shape[0],1))[:, :, np.newaxis]
offsetArr2 = np.random.randint(low=0, high=255, size=img.shape[0])
offsetMtx2 = np.tile(np.array([offsetArr2]).transpose(), (1, img.shape[1]))[:, :, np.newaxis]

offsetArr3 = np.random.randint(low=0, high=255, size=img.shape[1])
offsetMtx3 = np.tile(offsetArr3, (img.shape[0],1))[:, :, np.newaxis]
offsetArr4 = np.random.randint(low=0, high=255, size=img.shape[0])
offsetMtx4 = np.tile(np.array([offsetArr4]).transpose(), (1, img.shape[1]))[:, :, np.newaxis]

# %%
print(img.shape)
print(offsetMtx1.shape, offsetMtx2.shape)
# Out:
# (2362, 3496, 3)
# (2362, 3496, 1) (2362, 3496, 1)

# %%
img = img + (offsetMtx2 + offsetMtx1 + offsetMtx3 + offsetMtx4) / 4
plt.imshow(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
im = Image.fromarray(img)
im = Image.fromarray((x * 255).astype(np.uint8))
im.save("your_file.jpeg")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in fromarray(obj, mode)
#    2834         try:
# -> 2835             mode, rawmode = _fromarray_typemap[typekey]
#    2836         except KeyError as e:
#
# KeyError: ((1, 1, 3), '<i8')
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-6b12d753f5af> in <module>
# ----> 1 im = Image.fromarray(img)
#       2 im.save("your_file.jpeg")
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in fromarray(obj, mode)
#    2835             mode, rawmode = _fromarray_typemap[typekey]
#    2836         except KeyError as e:
# -> 2837             raise TypeError("Cannot handle this data type: %s, %s" % typekey) from e
#    2838     else:
# ...

# %%
img = img * 5 - offsetMtx1 - offsetMtx2 - offsetMtx3 - offsetMtx4

# %%
plt.imshow(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def restore(matrix, val):
    return matrix - val

# %%
np.random.seed(240)
offsetArr = np.random.randint(low=0, high=255, size=img.shape[0])
recover = np.vectorize(restore)
for i in range(img.shape[0]):
    img[i] = recover(img[i], offsetArr[i])

# %%
plt.imshow(img)

# %%
img.shape[:2]
# Out:
# (2362, 3496)

# %%
offsetArr1 = np.random.randint(low=0, high=255, size=5)
offsetArr1
# Out:
# array([210, 233,   7, 113,  31])

# %%
offsetMtx1 = np.tile(offsetArr1, (5,  1))
offsetMtx1
# Out:
# array([[210, 233,   7, 113,  31],
#        [210, 233,   7, 113,  31],
#        [210, 233,   7, 113,  31],
#        [210, 233,   7, 113,  31],
#        [210, 233,   7, 113,  31]])

# %%
offsetMtx1 = np.tile(offsetArr1, (5, 3,  1))
offsetMtx1
# Out:
# array([[[210, 233,   7, 113,  31],
#         [210, 233,   7, 113,  31],
#         [210, 233,   7, 113,  31]],
#
#        [[210, 233,   7, 113,  31],
#         [210, 233,   7, 113,  31],
#         [210, 233,   7, 113,  31]],
#
#        [[210, 233,   7, 113,  31],
#         [210, 233,   7, 113,  31],
#         [210, 233,   7, 113,  31]],
#
#        [[210, 233,   7, 113,  31],
#         [210, 233,   7, 113,  31],
#         [210, 233,   7, 113,  31]],
#
#        [[210, 233,   7, 113,  31],
#         [210, 233,   7, 113,  31],
#         [210, 233,   7, 113,  31]]])

# %%
offsetArr1 = np.random.randint(low=0, high=255, size=5)
offsetMtx1 = np.tile(np.array([offsetArr1]).transpose(), (1, 5))
offsetArr1
# Out:
# array([176,   3, 249,  97,  31])

# %%
offsetMtx1
# Out:
# array([[176, 176, 176, 176, 176],
#        [  3,   3,   3,   3,   3],
#        [249, 249, 249, 249, 249],
#        [ 97,  97,  97,  97,  97],
#        [ 31,  31,  31,  31,  31]])
